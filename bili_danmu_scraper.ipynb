# %%
import requests
import time
import json
import os
from datetime import datetime

# 设置请求的headers
headers = {
    'User-Agent': '"Microsoft Edge";v="131", "Chromium";v="131", "Not_A Brand";v="24"'
}

# 直播间ID
room_id = 32805602
nickname = "zzz1.4开服测试"

# 抓取弹幕设置
interval = 1
stop_after = 600

# 请求URL
url = f'https://api.live.bilibili.com/xlive/web-room/v1/dM/gethistory?roomid={room_id}&room_type=0'

# 创建存储文件夹
output_dir = "live_raw_response"
os.makedirs(output_dir, exist_ok=True)

# 动态生成文件名，包含开始抓取时间
start_time_str = datetime.now().strftime('%Y%m%d_%H%M%S')
if nickname is None:
    filename = os.path.join(output_dir, f'response_{room_id}_{start_time_str}.txt')
else:
    filename = os.path.join(output_dir, f'response_{nickname}_{start_time_str}.txt')

# 存储已记录弹幕的集合
unique_danmu_ids = set()

def fetch_and_save_danmu():
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # 检查请求是否成功
        
        # 将响应内容解析为JSON
        data = response.json()
        
        # 提取弹幕列表
        room_data = data.get('data', {}).get('room', [])
        if not isinstance(room_data, list):
            return 0
        
        new_danmu_count = 0
        with open(filename, 'a', encoding='utf-8') as file:
            for danmu in room_data:
                danmu_id = danmu.get('id_str')
                if danmu_id and danmu_id not in unique_danmu_ids:
                    # 记录新弹幕
                    unique_danmu_ids.add(danmu_id)
                    file.write(json.dumps(danmu, ensure_ascii=False) + '\n')
                    new_danmu_count += 1
        return new_danmu_count

    except requests.RequestException as e:
        print(f"请求出错: {e}")
        return 0

# 定时任务: 每隔数秒获取一次数据，直到达到指定的停止时间
def periodic_task(interval, stop_after):
    start_time_str_short = datetime.now().strftime(f'%H:%M')
    print(f"{start_time_str_short}开始抓取弹幕数据，每隔 {interval} 秒抓取一次，程序将在 {stop_after} 秒后停止...")
    start_time = time.time()
    total_danmu = 0
    while True:
        current_time = time.time()
        elapsed_time = current_time - start_time
        if elapsed_time > stop_after:
            end_time_str = datetime.now().strftime(f'%H:%M')
            print(f"抓取任务在{end_time_str}结束。")
            break
        
        # 获取并保存弹幕，并统计数量
        new_danmu_count = fetch_and_save_danmu()
        total_danmu += new_danmu_count
        remaining_time = max(0, stop_after - elapsed_time)

        # 打印统计信息
        print(f"已运行 {int(elapsed_time)} 秒，新增 {new_danmu_count} 条弹幕，已累计抓取 {total_danmu} 条弹幕。剩余 {int(remaining_time)} 秒。")

        time.sleep(interval)

    # 打印总弹幕统计
    print(f"共抓取了 {total_danmu} 条弹幕。")

if __name__ == "__main__":
    periodic_task(interval, stop_after)
# Out:
# 16:38开始抓取弹幕数据，每隔 1 秒抓取一次，程序将在 600 秒后停止...
# 已运行 0 秒，新增 10 条弹幕，已累计抓取 10 条弹幕。剩余 600 秒。
# 已运行 1 秒，新增 0 条弹幕，已累计抓取 10 条弹幕。剩余 598 秒。
# 已运行 2 秒，新增 0 条弹幕，已累计抓取 10 条弹幕。剩余 597 秒。
# 已运行 3 秒，新增 6 条弹幕，已累计抓取 16 条弹幕。剩余 596 秒。
# 已运行 4 秒，新增 0 条弹幕，已累计抓取 16 条弹幕。剩余 595 秒。
# 已运行 5 秒，新增 0 条弹幕，已累计抓取 16 条弹幕。剩余 594 秒。
# 已运行 6 秒，新增 4 条弹幕，已累计抓取 20 条弹幕。剩余 593 秒。
# 已运行 7 秒，新增 0 条弹幕，已累计抓取 20 条弹幕。剩余 592 秒。
# 已运行 8 秒，新增 0 条弹幕，已累计抓取 20 条弹幕。剩余 591 秒。
# 已运行 9 秒，新增 5 条弹幕，已累计抓取 25 条弹幕。剩余 590 秒。
# 已运行 10 秒，新增 0 条弹幕，已累计抓取 25 条弹幕。剩余 589 秒。
# 已运行 11 秒，新增 1 条弹幕，已累计抓取 26 条弹幕。剩余 588 秒。
# 已运行 12 秒，新增 0 条弹幕，已累计抓取 26 条弹幕。剩余 587 秒。
# 已运行 13 秒，新增 0 条弹幕，已累计抓取 26 条弹幕。剩余 586 秒。
# 已运行 14 秒，新增 5 条弹幕，已累计抓取 31 条弹幕。剩余 585 秒。
# 已运行 16 秒，新增 0 条弹幕，已累计抓取 31 条弹幕。剩余 583 秒。
# 已运行 17 秒，新增 0 条弹幕，已累计抓取 31 条弹幕。剩余 582 秒。
# 已运行 18 秒，新增 8 条弹幕，已累计抓取 39 条弹幕。剩余 581 秒。
# 已运行 19 秒，新增 0 条弹幕，已累计抓取 39 条弹幕。剩余 580 秒。
# 已运行 20 秒，新增 0 条弹幕，已累计抓取 39 条弹幕。剩余 579 秒。
# 已运行 21 秒，新增 9 条弹幕，已累计抓取 48 条弹幕。剩余 578 秒。
# 已运行 22 秒，新增 0 条弹幕，已累计抓取 48 条弹幕。剩余 577 秒。
# 已运行 23 秒，新增 0 条弹幕，已累计抓取 48 条弹幕。剩余 576 秒。
# 已运行 24 秒，新增 3 条弹幕，已累计抓取 51 条弹幕。剩余 575 秒。
# 已运行 25 秒，新增 0 条弹幕，已累计抓取 51 条弹幕。剩余 574 秒。
# 已运行 26 秒，新增 2 条弹幕，已累计抓取 53 条弹幕。剩余 573 秒。
# 已运行 27 秒，新增 0 条弹幕，已累计抓取 53 条弹幕。剩余 572 秒。
# 已运行 28 秒，新增 0 条弹幕，已累计抓取 53 条弹幕。剩余 571 秒。
# 已运行 29 秒，新增 2 条弹幕，已累计抓取 55 条弹幕。剩余 570 秒。
# 已运行 31 秒，新增 0 条弹幕，已累计抓取 55 条弹幕。剩余 568 秒。
# 已运行 32 秒，新增 0 条弹幕，已累计抓取 55 条弹幕。剩余 567 秒。
# 已运行 33 秒，新增 3 条弹幕，已累计抓取 58 条弹幕。剩余 566 秒。
# 已运行 34 秒，新增 0 条弹幕，已累计抓取 58 条弹幕。剩余 565 秒。
# 已运行 35 秒，新增 0 条弹幕，已累计抓取 58 条弹幕。剩余 564 秒。
# 已运行 36 秒，新增 8 条弹幕，已累计抓取 66 条弹幕。剩余 563 秒。
# 已运行 37 秒，新增 0 条弹幕，已累计抓取 66 条弹幕。剩余 562 秒。
# 已运行 38 秒，新增 5 条弹幕，已累计抓取 71 条弹幕。剩余 561 秒。
# 已运行 39 秒，新增 0 条弹幕，已累计抓取 71 条弹幕。剩余 560 秒。
# 已运行 40 秒，新增 0 条弹幕，已累计抓取 71 条弹幕。剩余 559 秒。
# 已运行 41 秒，新增 5 条弹幕，已累计抓取 76 条弹幕。剩余 558 秒。
# 已运行 42 秒，新增 0 条弹幕，已累计抓取 76 条弹幕。剩余 557 秒。
# 已运行 44 秒，新增 0 条弹幕，已累计抓取 76 条弹幕。剩余 555 秒。
# 已运行 45 秒，新增 9 条弹幕，已累计抓取 85 条弹幕。剩余 554 秒。
# 已运行 46 秒，新增 0 条弹幕，已累计抓取 85 条弹幕。剩余 553 秒。
# 已运行 47 秒，新增 0 条弹幕，已累计抓取 85 条弹幕。剩余 552 秒。
# 已运行 48 秒，新增 3 条弹幕，已累计抓取 88 条弹幕。剩余 551 秒。
# 已运行 49 秒，新增 0 条弹幕，已累计抓取 88 条弹幕。剩余 550 秒。
# 已运行 50 秒，新增 0 条弹幕，已累计抓取 88 条弹幕。剩余 549 秒。
# 已运行 51 秒，新增 4 条弹幕，已累计抓取 92 条弹幕。剩余 548 秒。
# 已运行 52 秒，新增 0 条弹幕，已累计抓取 92 条弹幕。剩余 547 秒。
# 已运行 53 秒，新增 0 条弹幕，已累计抓取 92 条弹幕。剩余 546 秒。
# 已运行 54 秒，新增 8 条弹幕，已累计抓取 100 条弹幕。剩余 545 秒。
# 已运行 55 秒，新增 0 条弹幕，已累计抓取 100 条弹幕。剩余 544 秒。
# 已运行 56 秒，新增 0 条弹幕，已累计抓取 100 条弹幕。剩余 543 秒。
# 已运行 57 秒，新增 7 条弹幕，已累计抓取 107 条弹幕。剩余 542 秒。
# 已运行 59 秒，新增 0 条弹幕，已累计抓取 107 条弹幕。剩余 540 秒。
# 已运行 60 秒，新增 0 条弹幕，已累计抓取 107 条弹幕。剩余 539 秒。
# 已运行 61 秒，新增 10 条弹幕，已累计抓取 117 条弹幕。剩余 538 秒。
# 已运行 62 秒，新增 0 条弹幕，已累计抓取 117 条弹幕。剩余 537 秒。
# 已运行 63 秒，新增 0 条弹幕，已累计抓取 117 条弹幕。剩余 536 秒。
# 已运行 64 秒，新增 8 条弹幕，已累计抓取 125 条弹幕。剩余 535 秒。
# 已运行 65 秒，新增 0 条弹幕，已累计抓取 125 条弹幕。剩余 534 秒。
# 已运行 66 秒，新增 0 条弹幕，已累计抓取 125 条弹幕。剩余 533 秒。
# 已运行 67 秒，新增 5 条弹幕，已累计抓取 130 条弹幕。剩余 532 秒。
# 已运行 68 秒，新增 0 条弹幕，已累计抓取 130 条弹幕。剩余 531 秒。
# 已运行 69 秒，新增 6 条弹幕，已累计抓取 136 条弹幕。剩余 530 秒。
# 已运行 70 秒，新增 0 条弹幕，已累计抓取 136 条弹幕。剩余 529 秒。
# 已运行 71 秒，新增 0 条弹幕，已累计抓取 136 条弹幕。剩余 528 秒。
# 已运行 73 秒，新增 4 条弹幕，已累计抓取 140 条弹幕。剩余 526 秒。
# 已运行 74 秒，新增 0 条弹幕，已累计抓取 140 条弹幕。剩余 525 秒。
# 已运行 75 秒，新增 0 条弹幕，已累计抓取 140 条弹幕。剩余 524 秒。
# 已运行 76 秒，新增 8 条弹幕，已累计抓取 148 条弹幕。剩余 523 秒。
# 已运行 77 秒，新增 1 条弹幕，已累计抓取 149 条弹幕。剩余 522 秒。
# 已运行 78 秒，新增 0 条弹幕，已累计抓取 149 条弹幕。剩余 521 秒。
# 已运行 79 秒，新增 0 条弹幕，已累计抓取 149 条弹幕。剩余 520 秒。
# 已运行 80 秒，新增 6 条弹幕，已累计抓取 155 条弹幕。剩余 519 秒。
# 已运行 81 秒，新增 0 条弹幕，已累计抓取 155 条弹幕。剩余 518 秒。
# 已运行 82 秒，新增 0 条弹幕，已累计抓取 155 条弹幕。剩余 517 秒。
# 已运行 83 秒，新增 5 条弹幕，已累计抓取 160 条弹幕。剩余 516 秒。
# 已运行 84 秒，新增 0 条弹幕，已累计抓取 160 条弹幕。剩余 515 秒。
# 已运行 85 秒，新增 0 条弹幕，已累计抓取 160 条弹幕。剩余 514 秒。
# 已运行 86 秒，新增 4 条弹幕，已累计抓取 164 条弹幕。剩余 513 秒。
# 已运行 88 秒，新增 0 条弹幕，已累计抓取 164 条弹幕。剩余 511 秒。
# 已运行 89 秒，新增 0 条弹幕，已累计抓取 164 条弹幕。剩余 510 秒。
# 已运行 90 秒，新增 7 条弹幕，已累计抓取 171 条弹幕。剩余 509 秒。
# 已运行 91 秒，新增 0 条弹幕，已累计抓取 171 条弹幕。剩余 508 秒。
# 已运行 92 秒，新增 0 条弹幕，已累计抓取 171 条弹幕。剩余 507 秒。
# 已运行 93 秒，新增 4 条弹幕，已累计抓取 175 条弹幕。剩余 506 秒。
# 已运行 94 秒，新增 0 条弹幕，已累计抓取 175 条弹幕。剩余 505 秒。
# 已运行 95 秒，新增 0 条弹幕，已累计抓取 175 条弹幕。剩余 504 秒。
# 已运行 96 秒，新增 6 条弹幕，已累计抓取 181 条弹幕。剩余 503 秒。
# 已运行 97 秒，新增 0 条弹幕，已累计抓取 181 条弹幕。剩余 502 秒。
# 已运行 98 秒，新增 1 条弹幕，已累计抓取 182 条弹幕。剩余 501 秒。
# 已运行 99 秒，新增 0 条弹幕，已累计抓取 182 条弹幕。剩余 500 秒。
# 已运行 100 秒，新增 0 条弹幕，已累计抓取 182 条弹幕。剩余 499 秒。
# 已运行 102 秒，新增 6 条弹幕，已累计抓取 188 条弹幕。剩余 497 秒。
# 已运行 103 秒，新增 0 条弹幕，已累计抓取 188 条弹幕。剩余 496 秒。
# 已运行 104 秒，新增 0 条弹幕，已累计抓取 188 条弹幕。剩余 495 秒。
# 已运行 105 秒，新增 10 条弹幕，已累计抓取 198 条弹幕。剩余 494 秒。
# 已运行 106 秒，新增 0 条弹幕，已累计抓取 198 条弹幕。剩余 493 秒。
# 已运行 107 秒，新增 0 条弹幕，已累计抓取 198 条弹幕。剩余 492 秒。
# 已运行 108 秒，新增 2 条弹幕，已累计抓取 200 条弹幕。剩余 491 秒。
# 已运行 109 秒，新增 0 条弹幕，已累计抓取 200 条弹幕。剩余 490 秒。
# 已运行 110 秒，新增 0 条弹幕，已累计抓取 200 条弹幕。剩余 489 秒。
# 已运行 111 秒，新增 5 条弹幕，已累计抓取 205 条弹幕。剩余 488 秒。
# 已运行 112 秒，新增 0 条弹幕，已累计抓取 205 条弹幕。剩余 487 秒。
# 已运行 113 秒，新增 0 条弹幕，已累计抓取 205 条弹幕。剩余 486 秒。
# 已运行 114 秒，新增 7 条弹幕，已累计抓取 212 条弹幕。剩余 485 秒。
# 已运行 115 秒，新增 0 条弹幕，已累计抓取 212 条弹幕。剩余 484 秒。
# 已运行 116 秒，新增 0 条弹幕，已累计抓取 212 条弹幕。剩余 483 秒。
# 已运行 118 秒，新增 2 条弹幕，已累计抓取 214 条弹幕。剩余 481 秒。
# 已运行 119 秒，新增 0 条弹幕，已累计抓取 214 条弹幕。剩余 480 秒。
# 已运行 120 秒，新增 0 条弹幕，已累计抓取 214 条弹幕。剩余 479 秒。
# 已运行 121 秒，新增 3 条弹幕，已累计抓取 217 条弹幕。剩余 478 秒。
# 已运行 122 秒，新增 0 条弹幕，已累计抓取 217 条弹幕。剩余 477 秒。
# 已运行 123 秒，新增 0 条弹幕，已累计抓取 217 条弹幕。剩余 476 秒。
# 已运行 124 秒，新增 2 条弹幕，已累计抓取 219 条弹幕。剩余 475 秒。
# 已运行 125 秒，新增 0 条弹幕，已累计抓取 219 条弹幕。剩余 474 秒。
# 已运行 126 秒，新增 0 条弹幕，已累计抓取 219 条弹幕。剩余 473 秒。
# 已运行 127 秒，新增 5 条弹幕，已累计抓取 224 条弹幕。剩余 472 秒。
# 已运行 128 秒，新增 0 条弹幕，已累计抓取 224 条弹幕。剩余 471 秒。
# 已运行 129 秒，新增 0 条弹幕，已累计抓取 224 条弹幕。剩余 470 秒。
# 已运行 130 秒，新增 8 条弹幕，已累计抓取 232 条弹幕。剩余 469 秒。
# 已运行 131 秒，新增 0 条弹幕，已累计抓取 232 条弹幕。剩余 468 秒。
# 已运行 133 秒，新增 0 条弹幕，已累计抓取 232 条弹幕。剩余 466 秒。
# 已运行 134 秒，新增 4 条弹幕，已累计抓取 236 条弹幕。剩余 465 秒。
# 已运行 135 秒，新增 0 条弹幕，已累计抓取 236 条弹幕。剩余 464 秒。
# 已运行 136 秒，新增 0 条弹幕，已累计抓取 236 条弹幕。剩余 463 秒。
# 已运行 137 秒，新增 5 条弹幕，已累计抓取 241 条弹幕。剩余 462 秒。
# 已运行 138 秒，新增 0 条弹幕，已累计抓取 241 条弹幕。剩余 461 秒。
# 已运行 139 秒，新增 0 条弹幕，已累计抓取 241 条弹幕。剩余 460 秒。
# 已运行 140 秒，新增 6 条弹幕，已累计抓取 247 条弹幕。剩余 459 秒。
# 已运行 141 秒，新增 0 条弹幕，已累计抓取 247 条弹幕。剩余 458 秒。
# 已运行 142 秒，新增 0 条弹幕，已累计抓取 247 条弹幕。剩余 457 秒。
# 已运行 143 秒，新增 5 条弹幕，已累计抓取 252 条弹幕。剩余 456 秒。
# 已运行 144 秒，新增 0 条弹幕，已累计抓取 252 条弹幕。剩余 455 秒。
# 已运行 145 秒，新增 0 条弹幕，已累计抓取 252 条弹幕。剩余 454 秒。
# 已运行 146 秒，新增 4 条弹幕，已累计抓取 256 条弹幕。剩余 453 秒。
# 已运行 147 秒，新增 0 条弹幕，已累计抓取 256 条弹幕。剩余 452 秒。
# 已运行 149 秒，新增 0 条弹幕，已累计抓取 256 条弹幕。剩余 450 秒。
# 已运行 150 秒，新增 6 条弹幕，已累计抓取 262 条弹幕。剩余 449 秒。
# 已运行 151 秒，新增 0 条弹幕，已累计抓取 262 条弹幕。剩余 448 秒。
# 已运行 152 秒，新增 0 条弹幕，已累计抓取 262 条弹幕。剩余 447 秒。
# 已运行 153 秒，新增 4 条弹幕，已累计抓取 266 条弹幕。剩余 446 秒。
# 已运行 154 秒，新增 0 条弹幕，已累计抓取 266 条弹幕。剩余 445 秒。
# 已运行 155 秒，新增 0 条弹幕，已累计抓取 266 条弹幕。剩余 444 秒。
# 已运行 156 秒，新增 2 条弹幕，已累计抓取 268 条弹幕。剩余 443 秒。
# 已运行 157 秒，新增 0 条弹幕，已累计抓取 268 条弹幕。剩余 442 秒。
# 已运行 158 秒，新增 0 条弹幕，已累计抓取 268 条弹幕。剩余 441 秒。
# 已运行 159 秒，新增 0 条弹幕，已累计抓取 268 条弹幕。剩余 440 秒。
# 已运行 160 秒，新增 0 条弹幕，已累计抓取 268 条弹幕。剩余 439 秒。
# 已运行 161 秒，新增 7 条弹幕，已累计抓取 275 条弹幕。剩余 438 秒。
# 已运行 163 秒，新增 0 条弹幕，已累计抓取 275 条弹幕。剩余 436 秒。
# 已运行 164 秒，新增 0 条弹幕，已累计抓取 275 条弹幕。剩余 435 秒。
# 已运行 165 秒，新增 5 条弹幕，已累计抓取 280 条弹幕。剩余 434 秒。
# 已运行 166 秒，新增 0 条弹幕，已累计抓取 280 条弹幕。剩余 433 秒。
# 已运行 167 秒，新增 0 条弹幕，已累计抓取 280 条弹幕。剩余 432 秒。
# 已运行 168 秒，新增 4 条弹幕，已累计抓取 284 条弹幕。剩余 431 秒。
# 已运行 169 秒，新增 0 条弹幕，已累计抓取 284 条弹幕。剩余 430 秒。
# 已运行 170 秒，新增 1 条弹幕，已累计抓取 285 条弹幕。剩余 429 秒。
# 已运行 171 秒，新增 0 条弹幕，已累计抓取 285 条弹幕。剩余 428 秒。
# 已运行 172 秒，新增 0 条弹幕，已累计抓取 285 条弹幕。剩余 427 秒。
# 已运行 173 秒，新增 5 条弹幕，已累计抓取 290 条弹幕。剩余 426 秒。
# 已运行 174 秒，新增 0 条弹幕，已累计抓取 290 条弹幕。剩余 425 秒。
# 已运行 175 秒，新增 0 条弹幕，已累计抓取 290 条弹幕。剩余 424 秒。
# 已运行 176 秒，新增 6 条弹幕，已累计抓取 296 条弹幕。剩余 423 秒。
# 已运行 178 秒，新增 0 条弹幕，已累计抓取 296 条弹幕。剩余 421 秒。
# 已运行 179 秒，新增 0 条弹幕，已累计抓取 296 条弹幕。剩余 420 秒。
# 已运行 180 秒，新增 5 条弹幕，已累计抓取 301 条弹幕。剩余 419 秒。
# 已运行 181 秒，新增 0 条弹幕，已累计抓取 301 条弹幕。剩余 418 秒。
# 已运行 182 秒，新增 0 条弹幕，已累计抓取 301 条弹幕。剩余 417 秒。
# 已运行 183 秒，新增 5 条弹幕，已累计抓取 306 条弹幕。剩余 416 秒。
# 已运行 184 秒，新增 0 条弹幕，已累计抓取 306 条弹幕。剩余 415 秒。
# 已运行 185 秒，新增 0 条弹幕，已累计抓取 306 条弹幕。剩余 414 秒。
# 已运行 186 秒，新增 1 条弹幕，已累计抓取 307 条弹幕。剩余 413 秒。
# 已运行 187 秒，新增 2 条弹幕，已累计抓取 309 条弹幕。剩余 412 秒。
# 已运行 188 秒，新增 0 条弹幕，已累计抓取 309 条弹幕。剩余 411 秒。
# 已运行 189 秒，新增 0 条弹幕，已累计抓取 309 条弹幕。剩余 410 秒。
# 已运行 190 秒，新增 5 条弹幕，已累计抓取 314 条弹幕。剩余 409 秒。
# 已运行 191 秒，新增 0 条弹幕，已累计抓取 314 条弹幕。剩余 408 秒。
# 已运行 193 秒，新增 0 条弹幕，已累计抓取 314 条弹幕。剩余 406 秒。
# 已运行 194 秒，新增 8 条弹幕，已累计抓取 322 条弹幕。剩余 405 秒。
# 已运行 195 秒，新增 0 条弹幕，已累计抓取 322 条弹幕。剩余 404 秒。
# 已运行 196 秒，新增 0 条弹幕，已累计抓取 322 条弹幕。剩余 403 秒。
# 已运行 197 秒，新增 8 条弹幕，已累计抓取 330 条弹幕。剩余 402 秒。
# 已运行 198 秒，新增 0 条弹幕，已累计抓取 330 条弹幕。剩余 401 秒。
# 已运行 199 秒，新增 0 条弹幕，已累计抓取 330 条弹幕。剩余 400 秒。
# 已运行 200 秒，新增 6 条弹幕，已累计抓取 336 条弹幕。剩余 399 秒。
# 已运行 201 秒，新增 0 条弹幕，已累计抓取 336 条弹幕。剩余 398 秒。
# 已运行 202 秒，新增 0 条弹幕，已累计抓取 336 条弹幕。剩余 397 秒。
# 已运行 203 秒，新增 3 条弹幕，已累计抓取 339 条弹幕。剩余 396 秒。
# 已运行 204 秒，新增 0 条弹幕，已累计抓取 339 条弹幕。剩余 395 秒。
# 已运行 205 秒，新增 0 条弹幕，已累计抓取 339 条弹幕。剩余 394 秒。
# 已运行 206 秒，新增 9 条弹幕，已累计抓取 348 条弹幕。剩余 393 秒。
# 已运行 208 秒，新增 0 条弹幕，已累计抓取 348 条弹幕。剩余 391 秒。
# 已运行 209 秒，新增 0 条弹幕，已累计抓取 348 条弹幕。剩余 390 秒。
# 已运行 210 秒，新增 2 条弹幕，已累计抓取 350 条弹幕。剩余 389 秒。
# 已运行 211 秒，新增 0 条弹幕，已累计抓取 350 条弹幕。剩余 388 秒。
# 已运行 212 秒，新增 0 条弹幕，已累计抓取 350 条弹幕。剩余 387 秒。
# 已运行 213 秒，新增 5 条弹幕，已累计抓取 355 条弹幕。剩余 386 秒。
# 已运行 214 秒，新增 0 条弹幕，已累计抓取 355 条弹幕。剩余 385 秒。
# 已运行 215 秒，新增 0 条弹幕，已累计抓取 355 条弹幕。剩余 384 秒。
# 已运行 216 秒，新增 6 条弹幕，已累计抓取 361 条弹幕。剩余 383 秒。
# 已运行 217 秒，新增 0 条弹幕，已累计抓取 361 条弹幕。剩余 382 秒。
# 已运行 218 秒，新增 2 条弹幕，已累计抓取 363 条弹幕。剩余 381 秒。
# 已运行 219 秒，新增 0 条弹幕，已累计抓取 363 条弹幕。剩余 380 秒。
# 已运行 220 秒，新增 0 条弹幕，已累计抓取 363 条弹幕。剩余 379 秒。
# 已运行 221 秒，新增 8 条弹幕，已累计抓取 371 条弹幕。剩余 378 秒。
# 已运行 223 秒，新增 0 条弹幕，已累计抓取 371 条弹幕。剩余 376 秒。
# 已运行 224 秒，新增 0 条弹幕，已累计抓取 371 条弹幕。剩余 375 秒。
# 已运行 225 秒，新增 5 条弹幕，已累计抓取 376 条弹幕。剩余 374 秒。
# 已运行 226 秒，新增 0 条弹幕，已累计抓取 376 条弹幕。剩余 373 秒。
# 已运行 227 秒，新增 0 条弹幕，已累计抓取 376 条弹幕。剩余 372 秒。
# 已运行 228 秒，新增 8 条弹幕，已累计抓取 384 条弹幕。剩余 371 秒。
# 已运行 229 秒，新增 0 条弹幕，已累计抓取 384 条弹幕。剩余 370 秒。
# 已运行 230 秒，新增 2 条弹幕，已累计抓取 386 条弹幕。剩余 369 秒。
# 已运行 231 秒，新增 0 条弹幕，已累计抓取 386 条弹幕。剩余 368 秒。
# 已运行 232 秒，新增 2 条弹幕，已累计抓取 388 条弹幕。剩余 367 秒。
# 已运行 233 秒，新增 0 条弹幕，已累计抓取 388 条弹幕。剩余 366 秒。
# 已运行 234 秒，新增 0 条弹幕，已累计抓取 388 条弹幕。剩余 365 秒。
# 已运行 235 秒，新增 8 条弹幕，已累计抓取 396 条弹幕。剩余 364 秒。
# 已运行 236 秒，新增 0 条弹幕，已累计抓取 396 条弹幕。剩余 363 秒。
# 已运行 238 秒，新增 0 条弹幕，已累计抓取 396 条弹幕。剩余 361 秒。
# 已运行 239 秒，新增 9 条弹幕，已累计抓取 405 条弹幕。剩余 360 秒。
# 已运行 240 秒，新增 0 条弹幕，已累计抓取 405 条弹幕。剩余 359 秒。
# 已运行 241 秒，新增 0 条弹幕，已累计抓取 405 条弹幕。剩余 358 秒。
# 已运行 242 秒，新增 7 条弹幕，已累计抓取 412 条弹幕。剩余 357 秒。
# 已运行 243 秒，新增 1 条弹幕，已累计抓取 413 条弹幕。剩余 356 秒。
# 已运行 244 秒，新增 0 条弹幕，已累计抓取 413 条弹幕。剩余 355 秒。
# 已运行 245 秒，新增 0 条弹幕，已累计抓取 413 条弹幕。剩余 354 秒。
# 已运行 246 秒，新增 6 条弹幕，已累计抓取 419 条弹幕。剩余 353 秒。
# 已运行 247 秒，新增 0 条弹幕，已累计抓取 419 条弹幕。剩余 352 秒。
# 已运行 248 秒，新增 6 条弹幕，已累计抓取 425 条弹幕。剩余 351 秒。
# 已运行 249 秒，新增 0 条弹幕，已累计抓取 425 条弹幕。剩余 350 秒。
# 已运行 250 秒，新增 0 条弹幕，已累计抓取 425 条弹幕。剩余 349 秒。
# 已运行 251 秒，新增 5 条弹幕，已累计抓取 430 条弹幕。剩余 348 秒。
# 已运行 253 秒，新增 0 条弹幕，已累计抓取 430 条弹幕。剩余 346 秒。
# 已运行 254 秒，新增 0 条弹幕，已累计抓取 430 条弹幕。剩余 345 秒。
# 已运行 255 秒，新增 6 条弹幕，已累计抓取 436 条弹幕。剩余 344 秒。
# 已运行 256 秒，新增 0 条弹幕，已累计抓取 436 条弹幕。剩余 343 秒。
# 已运行 257 秒，新增 0 条弹幕，已累计抓取 436 条弹幕。剩余 342 秒。
# 已运行 258 秒，新增 6 条弹幕，已累计抓取 442 条弹幕。剩余 341 秒。
# 已运行 259 秒，新增 0 条弹幕，已累计抓取 442 条弹幕。剩余 340 秒。
# 已运行 260 秒，新增 0 条弹幕，已累计抓取 442 条弹幕。剩余 339 秒。
# 已运行 261 秒，新增 6 条弹幕，已累计抓取 448 条弹幕。剩余 338 秒。
# 已运行 262 秒，新增 0 条弹幕，已累计抓取 448 条弹幕。剩余 337 秒。
# 已运行 263 秒，新增 0 条弹幕，已累计抓取 448 条弹幕。剩余 336 秒。
# 已运行 264 秒，新增 6 条弹幕，已累计抓取 454 条弹幕。剩余 335 秒。
# 已运行 265 秒，新增 0 条弹幕，已累计抓取 454 条弹幕。剩余 334 秒。
# 已运行 267 秒，新增 0 条弹幕，已累计抓取 454 条弹幕。剩余 332 秒。
# 已运行 268 秒，新增 5 条弹幕，已累计抓取 459 条弹幕。剩余 331 秒。
# 已运行 269 秒，新增 0 条弹幕，已累计抓取 459 条弹幕。剩余 330 秒。
# 已运行 270 秒，新增 0 条弹幕，已累计抓取 459 条弹幕。剩余 329 秒。
# 已运行 271 秒，新增 7 条弹幕，已累计抓取 466 条弹幕。剩余 328 秒。
# 已运行 272 秒，新增 0 条弹幕，已累计抓取 466 条弹幕。剩余 327 秒。
# 已运行 273 秒，新增 0 条弹幕，已累计抓取 466 条弹幕。剩余 326 秒。
# 已运行 274 秒，新增 10 条弹幕，已累计抓取 476 条弹幕。剩余 325 秒。
# 已运行 275 秒，新增 0 条弹幕，已累计抓取 476 条弹幕。剩余 324 秒。
# 已运行 276 秒，新增 0 条弹幕，已累计抓取 476 条弹幕。剩余 323 秒。
# 已运行 277 秒，新增 6 条弹幕，已累计抓取 482 条弹幕。剩余 322 秒。
# 已运行 279 秒，新增 0 条弹幕，已累计抓取 482 条弹幕。剩余 320 秒。
# 已运行 280 秒，新增 0 条弹幕，已累计抓取 482 条弹幕。剩余 319 秒。
# 已运行 281 秒，新增 8 条弹幕，已累计抓取 490 条弹幕。剩余 318 秒。
# 已运行 282 秒，新增 0 条弹幕，已累计抓取 490 条弹幕。剩余 317 秒。
# 已运行 283 秒，新增 0 条弹幕，已累计抓取 490 条弹幕。剩余 316 秒。
# 已运行 284 秒，新增 8 条弹幕，已累计抓取 498 条弹幕。剩余 315 秒。
# 已运行 285 秒，新增 0 条弹幕，已累计抓取 498 条弹幕。剩余 314 秒。
# 已运行 286 秒，新增 0 条弹幕，已累计抓取 498 条弹幕。剩余 313 秒。
# 已运行 287 秒，新增 8 条弹幕，已累计抓取 506 条弹幕。剩余 312 秒。
# 已运行 288 秒，新增 0 条弹幕，已累计抓取 506 条弹幕。剩余 311 秒。
# 已运行 289 秒，新增 4 条弹幕，已累计抓取 510 条弹幕。剩余 310 秒。
# 已运行 290 秒，新增 0 条弹幕，已累计抓取 510 条弹幕。剩余 309 秒。
# 已运行 291 秒，新增 0 条弹幕，已累计抓取 510 条弹幕。剩余 308 秒。
# 已运行 292 秒，新增 7 条弹幕，已累计抓取 517 条弹幕。剩余 307 秒。
# 已运行 294 秒，新增 0 条弹幕，已累计抓取 517 条弹幕。剩余 305 秒。
# 已运行 295 秒，新增 0 条弹幕，已累计抓取 517 条弹幕。剩余 304 秒。
# 已运行 296 秒，新增 4 条弹幕，已累计抓取 521 条弹幕。剩余 303 秒。
# 已运行 297 秒，新增 0 条弹幕，已累计抓取 521 条弹幕。剩余 302 秒。
# 已运行 298 秒，新增 0 条弹幕，已累计抓取 521 条弹幕。剩余 301 秒。
# 已运行 299 秒，新增 4 条弹幕，已累计抓取 525 条弹幕。剩余 300 秒。
# 已运行 300 秒，新增 0 条弹幕，已累计抓取 525 条弹幕。剩余 299 秒。
# 已运行 301 秒，新增 0 条弹幕，已累计抓取 525 条弹幕。剩余 298 秒。
# 已运行 302 秒，新增 7 条弹幕，已累计抓取 532 条弹幕。剩余 297 秒。
# 已运行 303 秒，新增 0 条弹幕，已累计抓取 532 条弹幕。剩余 296 秒。
# 已运行 304 秒，新增 0 条弹幕，已累计抓取 532 条弹幕。剩余 295 秒。
# 已运行 305 秒，新增 0 条弹幕，已累计抓取 532 条弹幕。剩余 294 秒。
# 已运行 306 秒，新增 4 条弹幕，已累计抓取 536 条弹幕。剩余 293 秒。
# 已运行 307 秒，新增 0 条弹幕，已累计抓取 536 条弹幕。剩余 292 秒。
# 已运行 309 秒，新增 0 条弹幕，已累计抓取 536 条弹幕。剩余 290 秒。
# 已运行 310 秒，新增 4 条弹幕，已累计抓取 540 条弹幕。剩余 289 秒。
# 已运行 311 秒，新增 0 条弹幕，已累计抓取 540 条弹幕。剩余 288 秒。
# 已运行 312 秒，新增 0 条弹幕，已累计抓取 540 条弹幕。剩余 287 秒。
# 已运行 313 秒，新增 7 条弹幕，已累计抓取 547 条弹幕。剩余 286 秒。
# 已运行 314 秒，新增 0 条弹幕，已累计抓取 547 条弹幕。剩余 285 秒。
# 已运行 315 秒，新增 0 条弹幕，已累计抓取 547 条弹幕。剩余 284 秒。
# 已运行 316 秒，新增 4 条弹幕，已累计抓取 551 条弹幕。剩余 283 秒。
# 已运行 317 秒，新增 0 条弹幕，已累计抓取 551 条弹幕。剩余 282 秒。
# 已运行 318 秒，新增 0 条弹幕，已累计抓取 551 条弹幕。剩余 281 秒。
# 已运行 319 秒，新增 6 条弹幕，已累计抓取 557 条弹幕。剩余 280 秒。
# 已运行 320 秒，新增 0 条弹幕，已累计抓取 557 条弹幕。剩余 279 秒。
# 已运行 321 秒，新增 0 条弹幕，已累计抓取 557 条弹幕。剩余 278 秒。
# 已运行 322 秒，新增 6 条弹幕，已累计抓取 563 条弹幕。剩余 277 秒。
# 已运行 324 秒，新增 0 条弹幕，已累计抓取 563 条弹幕。剩余 275 秒。
# 已运行 325 秒，新增 0 条弹幕，已累计抓取 563 条弹幕。剩余 274 秒。
# 已运行 326 秒，新增 9 条弹幕，已累计抓取 572 条弹幕。剩余 273 秒。
# 已运行 327 秒，新增 0 条弹幕，已累计抓取 572 条弹幕。剩余 272 秒。
# 已运行 328 秒，新增 0 条弹幕，已累计抓取 572 条弹幕。剩余 271 秒。
# 已运行 329 秒，新增 6 条弹幕，已累计抓取 578 条弹幕。剩余 270 秒。
# 已运行 330 秒，新增 0 条弹幕，已累计抓取 578 条弹幕。剩余 269 秒。
# 已运行 331 秒，新增 0 条弹幕，已累计抓取 578 条弹幕。剩余 268 秒。
# 已运行 332 秒，新增 10 条弹幕，已累计抓取 588 条弹幕。剩余 267 秒。
# 已运行 333 秒，新增 0 条弹幕，已累计抓取 588 条弹幕。剩余 266 秒。
# 已运行 334 秒，新增 1 条弹幕，已累计抓取 589 条弹幕。剩余 265 秒。
# 已运行 335 秒，新增 0 条弹幕，已累计抓取 589 条弹幕。剩余 264 秒。
# 已运行 336 秒，新增 0 条弹幕，已累计抓取 589 条弹幕。剩余 263 秒。
# 已运行 337 秒，新增 6 条弹幕，已累计抓取 595 条弹幕。剩余 262 秒。
# 已运行 339 秒，新增 0 条弹幕，已累计抓取 595 条弹幕。剩余 260 秒。
# 已运行 340 秒，新增 5 条弹幕，已累计抓取 600 条弹幕。剩余 259 秒。
# 已运行 341 秒，新增 0 条弹幕，已累计抓取 600 条弹幕。剩余 258 秒。
# 已运行 342 秒，新增 0 条弹幕，已累计抓取 600 条弹幕。剩余 257 秒。
# 已运行 343 秒，新增 2 条弹幕，已累计抓取 602 条弹幕。剩余 256 秒。
# 已运行 344 秒，新增 0 条弹幕，已累计抓取 602 条弹幕。剩余 255 秒。
# 已运行 345 秒，新增 0 条弹幕，已累计抓取 602 条弹幕。剩余 254 秒。
# 已运行 346 秒，新增 9 条弹幕，已累计抓取 611 条弹幕。剩余 253 秒。
# 已运行 347 秒，新增 0 条弹幕，已累计抓取 611 条弹幕。剩余 252 秒。
# 已运行 348 秒，新增 0 条弹幕，已累计抓取 611 条弹幕。剩余 251 秒。
# 已运行 349 秒，新增 8 条弹幕，已累计抓取 619 条弹幕。剩余 250 秒。
# 已运行 350 秒，新增 0 条弹幕，已累计抓取 619 条弹幕。剩余 249 秒。
# 已运行 351 秒，新增 0 条弹幕，已累计抓取 619 条弹幕。剩余 248 秒。
# 已运行 352 秒，新增 10 条弹幕，已累计抓取 629 条弹幕。剩余 247 秒。
# 已运行 354 秒，新增 0 条弹幕，已累计抓取 629 条弹幕。剩余 245 秒。
# 已运行 355 秒，新增 0 条弹幕，已累计抓取 629 条弹幕。剩余 244 秒。
# 已运行 356 秒，新增 6 条弹幕，已累计抓取 635 条弹幕。剩余 243 秒。
# 已运行 357 秒，新增 0 条弹幕，已累计抓取 635 条弹幕。剩余 242 秒。
# 已运行 358 秒，新增 0 条弹幕，已累计抓取 635 条弹幕。剩余 241 秒。
# 已运行 359 秒，新增 7 条弹幕，已累计抓取 642 条弹幕。剩余 240 秒。
# 已运行 360 秒，新增 0 条弹幕，已累计抓取 642 条弹幕。剩余 239 秒。
# 已运行 361 秒，新增 0 条弹幕，已累计抓取 642 条弹幕。剩余 238 秒。
# 已运行 362 秒，新增 7 条弹幕，已累计抓取 649 条弹幕。剩余 237 秒。
# 已运行 363 秒，新增 0 条弹幕，已累计抓取 649 条弹幕。剩余 236 秒。
# 已运行 364 秒，新增 1 条弹幕，已累计抓取 650 条弹幕。剩余 235 秒。
# 已运行 365 秒，新增 0 条弹幕，已累计抓取 650 条弹幕。剩余 234 秒。
# 已运行 366 秒，新增 0 条弹幕，已累计抓取 650 条弹幕。剩余 233 秒。
# 已运行 367 秒，新增 5 条弹幕，已累计抓取 655 条弹幕。剩余 232 秒。
# 已运行 369 秒，新增 0 条弹幕，已累计抓取 655 条弹幕。剩余 230 秒。
# 已运行 370 秒，新增 0 条弹幕，已累计抓取 655 条弹幕。剩余 229 秒。
# 已运行 371 秒，新增 6 条弹幕，已累计抓取 661 条弹幕。剩余 228 秒。
# 已运行 372 秒，新增 0 条弹幕，已累计抓取 661 条弹幕。剩余 227 秒。
# 已运行 373 秒，新增 0 条弹幕，已累计抓取 661 条弹幕。剩余 226 秒。
# 已运行 374 秒，新增 4 条弹幕，已累计抓取 665 条弹幕。剩余 225 秒。
# 已运行 375 秒，新增 0 条弹幕，已累计抓取 665 条弹幕。剩余 224 秒。
# 已运行 376 秒，新增 0 条弹幕，已累计抓取 665 条弹幕。剩余 223 秒。
# 已运行 377 秒，新增 7 条弹幕，已累计抓取 672 条弹幕。剩余 222 秒。
# 已运行 378 秒，新增 0 条弹幕，已累计抓取 672 条弹幕。剩余 221 秒。
# 已运行 379 秒，新增 3 条弹幕，已累计抓取 675 条弹幕。剩余 220 秒。
# 已运行 380 秒，新增 0 条弹幕，已累计抓取 675 条弹幕。剩余 219 秒。
# 已运行 381 秒，新增 0 条弹幕，已累计抓取 675 条弹幕。剩余 218 秒。
# 已运行 382 秒，新增 6 条弹幕，已累计抓取 681 条弹幕。剩余 217 秒。
# 已运行 385 秒，新增 0 条弹幕，已累计抓取 681 条弹幕。剩余 214 秒。
# 已运行 386 秒，新增 8 条弹幕，已累计抓取 689 条弹幕。剩余 213 秒。
# 已运行 388 秒，新增 0 条弹幕，已累计抓取 689 条弹幕。剩余 211 秒。
# 已运行 389 秒，新增 0 条弹幕，已累计抓取 689 条弹幕。剩余 210 秒。
# 已运行 390 秒，新增 4 条弹幕，已累计抓取 693 条弹幕。剩余 209 秒。
# 已运行 391 秒，新增 0 条弹幕，已累计抓取 693 条弹幕。剩余 208 秒。
# 已运行 392 秒，新增 0 条弹幕，已累计抓取 693 条弹幕。剩余 207 秒。
# 已运行 393 秒，新增 6 条弹幕，已累计抓取 699 条弹幕。剩余 206 秒。
# 已运行 394 秒，新增 0 条弹幕，已累计抓取 699 条弹幕。剩余 205 秒。
# 已运行 395 秒，新增 0 条弹幕，已累计抓取 699 条弹幕。剩余 204 秒。
# 已运行 396 秒，新增 3 条弹幕，已累计抓取 702 条弹幕。剩余 203 秒。
# 已运行 397 秒，新增 0 条弹幕，已累计抓取 702 条弹幕。剩余 202 秒。
# 已运行 399 秒，新增 0 条弹幕，已累计抓取 702 条弹幕。剩余 200 秒。
# 已运行 400 秒，新增 4 条弹幕，已累计抓取 706 条弹幕。剩余 199 秒。
# 已运行 401 秒，新增 0 条弹幕，已累计抓取 706 条弹幕。剩余 198 秒。
# 已运行 402 秒，新增 0 条弹幕，已累计抓取 706 条弹幕。剩余 197 秒。
# 已运行 403 秒，新增 1 条弹幕，已累计抓取 707 条弹幕。剩余 196 秒。
# 已运行 404 秒，新增 0 条弹幕，已累计抓取 707 条弹幕。剩余 195 秒。
# 已运行 405 秒，新增 0 条弹幕，已累计抓取 707 条弹幕。剩余 194 秒。
# 已运行 406 秒，新增 2 条弹幕，已累计抓取 709 条弹幕。剩余 193 秒。
# 已运行 407 秒，新增 0 条弹幕，已累计抓取 709 条弹幕。剩余 192 秒。
# 已运行 408 秒，新增 0 条弹幕，已累计抓取 709 条弹幕。剩余 191 秒。
# 已运行 409 秒，新增 5 条弹幕，已累计抓取 714 条弹幕。剩余 190 秒。
# 已运行 410 秒，新增 0 条弹幕，已累计抓取 714 条弹幕。剩余 189 秒。
# 已运行 411 秒，新增 0 条弹幕，已累计抓取 714 条弹幕。剩余 188 秒。
# 已运行 412 秒，新增 8 条弹幕，已累计抓取 722 条弹幕。剩余 187 秒。
# 已运行 413 秒，新增 0 条弹幕，已累计抓取 722 条弹幕。剩余 186 秒。
# 已运行 415 秒，新增 0 条弹幕，已累计抓取 722 条弹幕。剩余 184 秒。
# 已运行 416 秒，新增 5 条弹幕，已累计抓取 727 条弹幕。剩余 183 秒。
# 已运行 417 秒，新增 0 条弹幕，已累计抓取 727 条弹幕。剩余 182 秒。
# 已运行 418 秒，新增 0 条弹幕，已累计抓取 727 条弹幕。剩余 181 秒。
# 已运行 419 秒，新增 7 条弹幕，已累计抓取 734 条弹幕。剩余 180 秒。
# 已运行 420 秒，新增 0 条弹幕，已累计抓取 734 条弹幕。剩余 179 秒。
# 已运行 421 秒，新增 0 条弹幕，已累计抓取 734 条弹幕。剩余 178 秒。
# 已运行 422 秒，新增 5 条弹幕，已累计抓取 739 条弹幕。剩余 177 秒。
# 已运行 423 秒，新增 0 条弹幕，已累计抓取 739 条弹幕。剩余 176 秒。
# 已运行 424 秒，新增 0 条弹幕，已累计抓取 739 条弹幕。剩余 175 秒。
# 已运行 425 秒，新增 5 条弹幕，已累计抓取 744 条弹幕。剩余 174 秒。
# 已运行 426 秒，新增 0 条弹幕，已累计抓取 744 条弹幕。剩余 173 秒。
# 已运行 427 秒，新增 0 条弹幕，已累计抓取 744 条弹幕。剩余 172 秒。
# 已运行 428 秒，新增 4 条弹幕，已累计抓取 748 条弹幕。剩余 171 秒。
# 已运行 430 秒，新增 0 条弹幕，已累计抓取 748 条弹幕。剩余 169 秒。
# 已运行 431 秒，新增 0 条弹幕，已累计抓取 748 条弹幕。剩余 168 秒。
# 已运行 432 秒，新增 4 条弹幕，已累计抓取 752 条弹幕。剩余 167 秒。
# 已运行 433 秒，新增 0 条弹幕，已累计抓取 752 条弹幕。剩余 166 秒。
# 已运行 434 秒，新增 0 条弹幕，已累计抓取 752 条弹幕。剩余 165 秒。
# 已运行 435 秒，新增 3 条弹幕，已累计抓取 755 条弹幕。剩余 164 秒。
# 已运行 436 秒，新增 0 条弹幕，已累计抓取 755 条弹幕。剩余 163 秒。
# 已运行 437 秒，新增 0 条弹幕，已累计抓取 755 条弹幕。剩余 162 秒。
# 已运行 438 秒，新增 3 条弹幕，已累计抓取 758 条弹幕。剩余 161 秒。
# 已运行 439 秒，新增 0 条弹幕，已累计抓取 758 条弹幕。剩余 160 秒。
# 已运行 440 秒，新增 0 条弹幕，已累计抓取 758 条弹幕。剩余 159 秒。
# 已运行 441 秒，新增 8 条弹幕，已累计抓取 766 条弹幕。剩余 158 秒。
# 已运行 442 秒，新增 0 条弹幕，已累计抓取 766 条弹幕。剩余 157 秒。
# 已运行 444 秒，新增 0 条弹幕，已累计抓取 766 条弹幕。剩余 155 秒。
# 已运行 445 秒，新增 5 条弹幕，已累计抓取 771 条弹幕。剩余 154 秒。
# 已运行 446 秒，新增 0 条弹幕，已累计抓取 771 条弹幕。剩余 153 秒。
# 已运行 447 秒，新增 0 条弹幕，已累计抓取 771 条弹幕。剩余 152 秒。
# 已运行 448 秒，新增 4 条弹幕，已累计抓取 775 条弹幕。剩余 151 秒。
# 已运行 449 秒，新增 0 条弹幕，已累计抓取 775 条弹幕。剩余 150 秒。
# 已运行 450 秒，新增 0 条弹幕，已累计抓取 775 条弹幕。剩余 149 秒。
# 已运行 451 秒，新增 3 条弹幕，已累计抓取 778 条弹幕。剩余 148 秒。
# 已运行 452 秒，新增 0 条弹幕，已累计抓取 778 条弹幕。剩余 147 秒。
# 已运行 453 秒，新增 0 条弹幕，已累计抓取 778 条弹幕。剩余 146 秒。
# 已运行 454 秒，新增 8 条弹幕，已累计抓取 786 条弹幕。剩余 145 秒。
# 已运行 455 秒，新增 0 条弹幕，已累计抓取 786 条弹幕。剩余 144 秒。
# 已运行 456 秒，新增 0 条弹幕，已累计抓取 786 条弹幕。剩余 143 秒。
# 已运行 457 秒，新增 1 条弹幕，已累计抓取 787 条弹幕。剩余 142 秒。
# 已运行 459 秒，新增 0 条弹幕，已累计抓取 787 条弹幕。剩余 140 秒。
# 已运行 460 秒，新增 0 条弹幕，已累计抓取 787 条弹幕。剩余 139 秒。
# 已运行 461 秒，新增 5 条弹幕，已累计抓取 792 条弹幕。剩余 138 秒。
# 已运行 462 秒，新增 0 条弹幕，已累计抓取 792 条弹幕。剩余 137 秒。
# 已运行 463 秒，新增 5 条弹幕，已累计抓取 797 条弹幕。剩余 136 秒。
# 已运行 464 秒，新增 0 条弹幕，已累计抓取 797 条弹幕。剩余 135 秒。
# 已运行 465 秒，新增 0 条弹幕，已累计抓取 797 条弹幕。剩余 134 秒。
# 已运行 466 秒，新增 9 条弹幕，已累计抓取 806 条弹幕。剩余 133 秒。
# 已运行 468 秒，新增 0 条弹幕，已累计抓取 806 条弹幕。剩余 131 秒。
# 已运行 469 秒，新增 0 条弹幕，已累计抓取 806 条弹幕。剩余 130 秒。
# 已运行 470 秒，新增 4 条弹幕，已累计抓取 810 条弹幕。剩余 129 秒。
# 已运行 471 秒，新增 0 条弹幕，已累计抓取 810 条弹幕。剩余 128 秒。
# 已运行 472 秒，新增 0 条弹幕，已累计抓取 810 条弹幕。剩余 127 秒。
# 已运行 473 秒，新增 7 条弹幕，已累计抓取 817 条弹幕。剩余 126 秒。
# 已运行 474 秒，新增 0 条弹幕，已累计抓取 817 条弹幕。剩余 125 秒。
# 已运行 475 秒，新增 0 条弹幕，已累计抓取 817 条弹幕。剩余 124 秒。
# 已运行 476 秒，新增 7 条弹幕，已累计抓取 824 条弹幕。剩余 123 秒。
# 已运行 477 秒，新增 0 条弹幕，已累计抓取 824 条弹幕。剩余 122 秒。
# 已运行 478 秒，新增 3 条弹幕，已累计抓取 827 条弹幕。剩余 121 秒。
# 已运行 479 秒，新增 0 条弹幕，已累计抓取 827 条弹幕。剩余 120 秒。
# 已运行 481 秒，新增 0 条弹幕，已累计抓取 827 条弹幕。剩余 118 秒。
# 已运行 482 秒，新增 7 条弹幕，已累计抓取 834 条弹幕。剩余 117 秒。
# 已运行 483 秒，新增 0 条弹幕，已累计抓取 834 条弹幕。剩余 116 秒。
# 已运行 484 秒，新增 0 条弹幕，已累计抓取 834 条弹幕。剩余 115 秒。
# 已运行 485 秒，新增 5 条弹幕，已累计抓取 839 条弹幕。剩余 114 秒。
# 已运行 486 秒，新增 0 条弹幕，已累计抓取 839 条弹幕。剩余 113 秒。
# 已运行 487 秒，新增 0 条弹幕，已累计抓取 839 条弹幕。剩余 112 秒。
# 已运行 488 秒，新增 6 条弹幕，已累计抓取 845 条弹幕。剩余 111 秒。
# 已运行 489 秒，新增 0 条弹幕，已累计抓取 845 条弹幕。剩余 110 秒。
# 已运行 490 秒，新增 4 条弹幕，已累计抓取 849 条弹幕。剩余 109 秒。
# 已运行 491 秒，新增 0 条弹幕，已累计抓取 849 条弹幕。剩余 108 秒。
# 已运行 493 秒，新增 0 条弹幕，已累计抓取 849 条弹幕。剩余 106 秒。
# 已运行 494 秒，新增 7 条弹幕，已累计抓取 856 条弹幕。剩余 105 秒。
# 已运行 495 秒，新增 0 条弹幕，已累计抓取 856 条弹幕。剩余 104 秒。
# 已运行 496 秒，新增 0 条弹幕，已累计抓取 856 条弹幕。剩余 103 秒。
# 已运行 497 秒，新增 8 条弹幕，已累计抓取 864 条弹幕。剩余 102 秒。
# 已运行 498 秒，新增 0 条弹幕，已累计抓取 864 条弹幕。剩余 101 秒。
# 已运行 499 秒，新增 0 条弹幕，已累计抓取 864 条弹幕。剩余 100 秒。
# 已运行 500 秒，新增 9 条弹幕，已累计抓取 873 条弹幕。剩余 99 秒。
# 已运行 501 秒，新增 0 条弹幕，已累计抓取 873 条弹幕。剩余 98 秒。
# 已运行 503 秒，新增 0 条弹幕，已累计抓取 873 条弹幕。剩余 96 秒。
# 已运行 504 秒，新增 10 条弹幕，已累计抓取 883 条弹幕。剩余 95 秒。
# 已运行 505 秒，新增 0 条弹幕，已累计抓取 883 条弹幕。剩余 94 秒。
# 已运行 506 秒，新增 0 条弹幕，已累计抓取 883 条弹幕。剩余 93 秒。
# 已运行 507 秒，新增 4 条弹幕，已累计抓取 887 条弹幕。剩余 92 秒。
# 已运行 508 秒，新增 0 条弹幕，已累计抓取 887 条弹幕。剩余 91 秒。
# 已运行 509 秒，新增 0 条弹幕，已累计抓取 887 条弹幕。剩余 90 秒。
# 已运行 510 秒，新增 4 条弹幕，已累计抓取 891 条弹幕。剩余 89 秒。
# 已运行 511 秒，新增 0 条弹幕，已累计抓取 891 条弹幕。剩余 88 秒。
# 已运行 512 秒，新增 0 条弹幕，已累计抓取 891 条弹幕。剩余 87 秒。
# 已运行 513 秒，新增 10 条弹幕，已累计抓取 901 条弹幕。剩余 86 秒。
# 已运行 514 秒，新增 0 条弹幕，已累计抓取 901 条弹幕。剩余 85 秒。
# 已运行 515 秒，新增 0 条弹幕，已累计抓取 901 条弹幕。剩余 84 秒。
# 已运行 516 秒，新增 3 条弹幕，已累计抓取 904 条弹幕。剩余 83 秒。
# 已运行 518 秒，新增 0 条弹幕，已累计抓取 904 条弹幕。剩余 81 秒。
# 已运行 519 秒，新增 0 条弹幕，已累计抓取 904 条弹幕。剩余 80 秒。
# 已运行 520 秒，新增 3 条弹幕，已累计抓取 907 条弹幕。剩余 79 秒。
# 已运行 521 秒，新增 0 条弹幕，已累计抓取 907 条弹幕。剩余 78 秒。
# 已运行 522 秒，新增 0 条弹幕，已累计抓取 907 条弹幕。剩余 77 秒。
# 已运行 523 秒，新增 5 条弹幕，已累计抓取 912 条弹幕。剩余 76 秒。
# 已运行 524 秒，新增 0 条弹幕，已累计抓取 912 条弹幕。剩余 75 秒。
# 已运行 525 秒，新增 0 条弹幕，已累计抓取 912 条弹幕。剩余 74 秒。
# 已运行 526 秒，新增 6 条弹幕，已累计抓取 918 条弹幕。剩余 73 秒。
# 已运行 527 秒，新增 0 条弹幕，已累计抓取 918 条弹幕。剩余 72 秒。
# 已运行 528 秒，新增 3 条弹幕，已累计抓取 921 条弹幕。剩余 71 秒。
# 已运行 529 秒，新增 0 条弹幕，已累计抓取 921 条弹幕。剩余 70 秒。
# 已运行 530 秒，新增 0 条弹幕，已累计抓取 921 条弹幕。剩余 69 秒。
# 已运行 531 秒，新增 6 条弹幕，已累计抓取 927 条弹幕。剩余 68 秒。
# 已运行 533 秒，新增 0 条弹幕，已累计抓取 927 条弹幕。剩余 66 秒。
# 已运行 534 秒，新增 0 条弹幕，已累计抓取 927 条弹幕。剩余 65 秒。
# 已运行 535 秒，新增 9 条弹幕，已累计抓取 936 条弹幕。剩余 64 秒。
# 已运行 536 秒，新增 0 条弹幕，已累计抓取 936 条弹幕。剩余 63 秒。
# 已运行 537 秒，新增 0 条弹幕，已累计抓取 936 条弹幕。剩余 62 秒。
# 已运行 538 秒，新增 3 条弹幕，已累计抓取 939 条弹幕。剩余 61 秒。
# 已运行 539 秒，新增 0 条弹幕，已累计抓取 939 条弹幕。剩余 60 秒。
# 已运行 540 秒，新增 0 条弹幕，已累计抓取 939 条弹幕。剩余 59 秒。
# 已运行 541 秒，新增 10 条弹幕，已累计抓取 949 条弹幕。剩余 58 秒。
# 已运行 542 秒，新增 0 条弹幕，已累计抓取 949 条弹幕。剩余 57 秒。
# 已运行 543 秒，新增 0 条弹幕，已累计抓取 949 条弹幕。剩余 56 秒。
# 已运行 544 秒，新增 0 条弹幕，已累计抓取 949 条弹幕。剩余 55 秒。
# 已运行 545 秒，新增 0 条弹幕，已累计抓取 949 条弹幕。剩余 54 秒。
# 已运行 546 秒，新增 7 条弹幕，已累计抓取 956 条弹幕。剩余 53 秒。
# 已运行 548 秒，新增 0 条弹幕，已累计抓取 956 条弹幕。剩余 51 秒。
# 已运行 549 秒，新增 0 条弹幕，已累计抓取 956 条弹幕。剩余 50 秒。
# 已运行 550 秒，新增 3 条弹幕，已累计抓取 959 条弹幕。剩余 49 秒。
# 已运行 551 秒，新增 0 条弹幕，已累计抓取 959 条弹幕。剩余 48 秒。
# 已运行 552 秒，新增 0 条弹幕，已累计抓取 959 条弹幕。剩余 47 秒。
# 已运行 553 秒，新增 2 条弹幕，已累计抓取 961 条弹幕。剩余 46 秒。
# 已运行 554 秒，新增 0 条弹幕，已累计抓取 961 条弹幕。剩余 45 秒。
# 已运行 555 秒，新增 0 条弹幕，已累计抓取 961 条弹幕。剩余 44 秒。
# 已运行 556 秒，新增 10 条弹幕，已累计抓取 971 条弹幕。剩余 43 秒。
# 已运行 557 秒，新增 0 条弹幕，已累计抓取 971 条弹幕。剩余 42 秒。
# 已运行 558 秒，新增 1 条弹幕，已累计抓取 972 条弹幕。剩余 41 秒。
# 已运行 559 秒，新增 0 条弹幕，已累计抓取 972 条弹幕。剩余 40 秒。
# 已运行 560 秒，新增 0 条弹幕，已累计抓取 972 条弹幕。剩余 39 秒。
# 已运行 561 秒，新增 5 条弹幕，已累计抓取 977 条弹幕。剩余 38 秒。
# 已运行 563 秒，新增 0 条弹幕，已累计抓取 977 条弹幕。剩余 36 秒。
# 已运行 564 秒，新增 0 条弹幕，已累计抓取 977 条弹幕。剩余 35 秒。
# 已运行 565 秒，新增 0 条弹幕，已累计抓取 977 条弹幕。剩余 34 秒。
# 已运行 566 秒，新增 0 条弹幕，已累计抓取 977 条弹幕。剩余 33 秒。
# 已运行 567 秒，新增 0 条弹幕，已累计抓取 977 条弹幕。剩余 32 秒。
# 已运行 568 秒，新增 6 条弹幕，已累计抓取 983 条弹幕。剩余 31 秒。
# 已运行 569 秒，新增 0 条弹幕，已累计抓取 983 条弹幕。剩余 30 秒。
# 已运行 570 秒，新增 0 条弹幕，已累计抓取 983 条弹幕。剩余 29 秒。
# 已运行 571 秒，新增 4 条弹幕，已累计抓取 987 条弹幕。剩余 28 秒。
# 已运行 572 秒，新增 0 条弹幕，已累计抓取 987 条弹幕。剩余 27 秒。
# 已运行 573 秒，新增 2 条弹幕，已累计抓取 989 条弹幕。剩余 26 秒。
# 已运行 574 秒，新增 0 条弹幕，已累计抓取 989 条弹幕。剩余 25 秒。
# 已运行 575 秒，新增 0 条弹幕，已累计抓取 989 条弹幕。剩余 24 秒。
# 已运行 576 秒，新增 4 条弹幕，已累计抓取 993 条弹幕。剩余 23 秒。
# 已运行 578 秒，新增 0 条弹幕，已累计抓取 993 条弹幕。剩余 21 秒。
# 已运行 579 秒，新增 0 条弹幕，已累计抓取 993 条弹幕。剩余 20 秒。
# 已运行 580 秒，新增 4 条弹幕，已累计抓取 997 条弹幕。剩余 19 秒。
# 已运行 581 秒，新增 0 条弹幕，已累计抓取 997 条弹幕。剩余 18 秒。
# 已运行 582 秒，新增 0 条弹幕，已累计抓取 997 条弹幕。剩余 17 秒。
# 已运行 583 秒，新增 8 条弹幕，已累计抓取 1005 条弹幕。剩余 16 秒。
# 已运行 584 秒，新增 0 条弹幕，已累计抓取 1005 条弹幕。剩余 15 秒。
# 已运行 585 秒，新增 0 条弹幕，已累计抓取 1005 条弹幕。剩余 14 秒。
# 已运行 586 秒，新增 8 条弹幕，已累计抓取 1013 条弹幕。剩余 13 秒。
# 已运行 587 秒，新增 0 条弹幕，已累计抓取 1013 条弹幕。剩余 12 秒。
# 已运行 588 秒，新增 2 条弹幕，已累计抓取 1015 条弹幕。剩余 11 秒。
# 已运行 589 秒，新增 1 条弹幕，已累计抓取 1016 条弹幕。剩余 10 秒。
# 已运行 590 秒，新增 0 条弹幕，已累计抓取 1016 条弹幕。剩余 9 秒。
# 已运行 591 秒，新增 0 条弹幕，已累计抓取 1016 条弹幕。剩余 8 秒。
# 已运行 593 秒，新增 8 条弹幕，已累计抓取 1024 条弹幕。剩余 6 秒。
# 已运行 594 秒，新增 0 条弹幕，已累计抓取 1024 条弹幕。剩余 5 秒。
# 已运行 595 秒，新增 0 条弹幕，已累计抓取 1024 条弹幕。剩余 4 秒。
# 已运行 596 秒，新增 2 条弹幕，已累计抓取 1026 条弹幕。剩余 3 秒。
# 已运行 597 秒，新增 0 条弹幕，已累计抓取 1026 条弹幕。剩余 2 秒。
# 已运行 598 秒，新增 0 条弹幕，已累计抓取 1026 条弹幕。剩余 1 秒。
# 已运行 599 秒，新增 5 条弹幕，已累计抓取 1031 条弹幕。剩余 0 秒。
# 抓取任务在16:48结束。
# 共抓取了 1031 条弹幕。
